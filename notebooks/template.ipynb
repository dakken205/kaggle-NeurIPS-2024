# %% [markdown]
# # ノートブック概要
#
# ここにノートブックで行っていることの概要，目的等を記入
#
# <!-- 目次（必要に応じて） -->
# <!-- 1.  -->
# <!-- 2.  -->
# <!-- 3.  -->

# %% [markdown]
# # 環境構築

# %%
# !pip install -r https://raw.githubusercontent.com/dakken205/kaggle-NeurIPS-2024/main/requirements.txt
# !git clone https://github.com/dakken205/kaggle-NeurIPS-2024.git

import sys
sys.path.append('/kaggle/working/kaggle-NeurIPS-2024')
# Out:
# fatal: destination path 'kaggle-NeurIPS-2024' already exists and is not an empty directory.

# %%
from src.utils import sample
from src.utils.sample import print_hello

sample.print_hello()
print_hello()
# Out:
# Hello world.
# Hello world.

# %% [markdown]
# ## 作業
